# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Cargar MNIST
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Preprocesamiento
x_train = x_train.reshape(-1, 784) / 255.0
x_test  = x_test.reshape(-1, 784) / 255.0

# One-hot
y_train = keras.utils.to_categorical(y_train, 10)
y_test  = keras.utils.to_categorical(y_test, 10)

# Construcción de la red
model = keras.Sequential([
    layers.Input(shape=(784,)),
    layers.Dense(30, activation="sigmoid"),
    layers.Dense(10, activation="sigmoid")
])

# SGD con tasa 0.5 igual al original
optimizer = keras.optimizers.Adam(learning_rate=0.001)

# Costo cuadrático para replicar exactamente tu código original
model.compile(
    optimizer=optimizer,
    loss="mean_squared_error",
    metrics=["accuracy"]
)

# Entrenamiento equivalente (15 épocas, batch 10)
model.fit(
    x_train, y_train,
    epochs=15,
    batch_size=10,
    validation_data=(x_test, y_test)
)

# Guardar el modelo
model.save("red_prueba.keras")
print("Entrenamiento terminado y red guardada en red_prueba.keras")
# Out:
# WARNING:tensorflow:From c:\Users\Noe\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# WARNING:tensorflow:From c:\Users\Noe\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/15
# WARNING:tensorflow:From c:\Users\Noe\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Noe\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6000/6000 [==============================] - 6s 912us/step - loss: 0.0408 - accuracy: 0.7927 - val_loss: 0.0221 - val_accuracy: 0.8931
# Epoch 2/15
# 6000/6000 [==============================] - 5s 898us/step - loss: 0.0195 - accuracy: 0.8983 - val_loss: 0.0166 - val_accuracy: 0.9108
# Epoch 3/15
# 6000/6000 [==============================] - 5s 902us/step - loss: 0.0160 - accuracy: 0.9110 - val_loss: 0.0144 - val_accuracy: 0.9204
# Epoch 4/15
# 6000/6000 [==============================] - 5s 889us/step - loss: 0.0143 - accuracy: 0.9194 - val_loss: 0.0132 - val_accuracy: 0.9261
# Epoch 5/15
# 6000/6000 [==============================] - 5s 900us/step - loss: 0.0132 - accuracy: 0.9247 - val_loss: 0.0124 - val_accuracy: 0.9308
# Epoch 6/15
# 6000/6000 [==============================] - 5s 881us/step - loss: 0.0124 - accuracy: 0.9289 - val_loss: 0.0117 - val_accuracy: 0.9345
# Epoch 7/15
# 6000/6000 [==============================] - 6s 926us/step - loss: 0.0117 - accuracy: 0.9330 - val_loss: 0.0112 - val_accuracy: 0.9357
# Epoch 8/15
# 6000/6000 [==============================] - 5s 914us/step - loss: 0.0112 - accuracy: 0.9358 - val_loss: 0.0108 - val_accuracy: 0.9381
# Epoch 9/15
# 6000/6000 [==============================] - 6s 926us/step - loss: 0.0108 - accuracy: 0.9389 - val_loss: 0.0106 - val_accuracy: 0.9393
# Epoch 10/15
# 6000/6000 [==============================] - 6s 961us/step - loss: 0.0104 - accuracy: 0.9410 - val_loss: 0.0102 - val_accuracy: 0.9403
# Epoch 11/15
# 6000/6000 [==============================] - 6s 920us/step - loss: 0.0100 - accuracy: 0.9432 - val_loss: 0.0100 - val_accuracy: 0.9415
# Epoch 12/15
# 6000/6000 [==============================] - 6s 917us/step - loss: 0.0098 - accuracy: 0.9451 - val_loss: 0.0098 - val_accuracy: 0.9431
# Epoch 13/15
# 6000/6000 [==============================] - 5s 885us/step - loss: 0.0095 - accuracy: 0.9465 - val_loss: 0.0096 - val_accuracy: 0.9430
# Epoch 14/15
# 6000/6000 [==============================] - 5s 884us/step - loss: 0.0093 - accuracy: 0.9477 - val_loss: 0.0094 - val_accuracy: 0.9441
# Epoch 15/15
# 6000/6000 [==============================] - 5s 862us/step - loss: 0.0091 - accuracy: 0.9492 - val_loss: 0.0093 - val_accuracy: 0.9450
# Entrenamiento terminado y red guardada en red_prueba.keras
